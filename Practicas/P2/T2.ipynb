# %% [markdown]
# ## Tarea
#
# Fragoso Alvarado Daniel | 316049054

# %%
# Importamos librerias
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %% [markdown]
# ### Línea Recta.
#
# Vamos a crear la imagen base y posteriormente una línea recta.

# %%
# Definimos el fondo de la imagen
image = np.zeros(shape=(500, 500), dtype=np.int16)

plt.imshow(image)

# %%
# Definimos el fondo de la imagen
image = np.zeros(shape=(500, 500), dtype=np.int16)
# Dibujemos una línea:
linea = cv2.line(image, (0, 0), (500, 500), 2)

plt.imshow(linea)

# %%
# Ahora vamos a dibujara  aprtir de puras líneas rectas 
# una ilusión mediate un comando for

# Definimos el fondo de la imagen
image = np.zeros(shape=(500, 500), dtype=np.int16)
# Dibujemos una línea:
#linea = cv2.line(image, (0, 0), (500, 500), 2)

for x in range(0, 500, 50):
    linea = cv2.line(image, (x, 500), (0, x), (50, 50, 0), 5)
    plt.imshow(linea)

# %% [markdown]
# ### Rectangulo
#
# Vamos a agregar un rectangulo

# %%
rectan = cv2.rectangle(image, (120, 370), (500, 0), (100, 50, 50), 5)
plt.imshow(rectan)

# %% [markdown]
# ### Circulo

# %%
image = cv2.circle(image, (310, 185), 150, (255, 255, 0), -1)
plt.imshow(image)

# %% [markdown]
# ### Texto

# %%
# Vamos a definir el tipo de texto que queremos usar
# En este caso será como manuscrita
font = cv2.FONT_HERSHEY_SCRIPT_COMPLEX
# escribimos el texto
text = cv2.putText(image, 'DFA', (250, 200), font, 2, (0, 0, 0), 2, cv2.LINE_AA)
plt.imshow(text)
